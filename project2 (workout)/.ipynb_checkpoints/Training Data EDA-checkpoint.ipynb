# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
housing = pd.read_csv('datasets/train.csv')

housing.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour  ... Screen Porch Pool Area Pool QC Fence  \
# 0       IR1          Lvl  ...            0         0     NaN   NaN
# 1       IR1          Lvl  ...            0         0     NaN   NaN
# 2       Reg          Lvl  ...            0         0     NaN   NaN
# 3       Reg          Lvl  ...            0         0     NaN   NaN
# 4       IR1          Lvl  ...            0         0     NaN   NaN
#
#   Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  SalePrice
# 0          NaN        0       3    2010        WD      130500
# 1          NaN        0       4    2009        WD      220000
# 2          NaN        0       1    2010        WD      109000
# 3          NaN        0       4    2010        WD      174000
# 4          NaN        0       3    2010        WD      138500
#
# [5 rows x 81 columns]

# %%
housing.shape
# Out:
# (2051, 81)

# %%
housing.set_index('Id', inplace = True)

# %%
null_features = housing.isnull().sum().sort_values(ascending = False).to_frame(name = 'nullcount')

null_features.head(20)
# Out:
#                 nullcount
# Pool QC              2042
# Misc Feature         1986
# Alley                1911
# Fence                1651
# Fireplace Qu         1000
# Lot Frontage          330
# Garage Qual           114
# Garage Finish         114
# Garage Cond           114
# Garage Yr Blt         114
# Garage Type           113
# Bsmt Exposure          58
# BsmtFin Type 2         56
# Bsmt Cond              55
# Bsmt Qual              55
# BsmtFin Type 1         55
# Mas Vnr Type           22
# Mas Vnr Area           22
# Bsmt Half Bath          2
# Bsmt Full Bath          2

# %%
null_drop_cond = (null_features['nullcount'] > 0) & (null_features['nullcount'] < 100)
null_features_todrop = null_features[null_drop_cond]
null_features_todrop
# Out:
#                 nullcount
# Bsmt Exposure          58
# BsmtFin Type 2         56
# Bsmt Cond              55
# Bsmt Qual              55
# BsmtFin Type 1         55
# Mas Vnr Type           22
# Mas Vnr Area           22
# Bsmt Half Bath          2
# Bsmt Full Bath          2
# Garage Cars             1
# Garage Area             1
# Total Bsmt SF           1
# Bsmt Unf SF             1
# BsmtFin SF 2            1
# BsmtFin SF 1            1

# %%
nulldrop_list = null_features_todrop.index.to_list()
nulldrop_list
# Out:
# ['Bsmt Exposure',
#  'BsmtFin Type 2',
#  'Bsmt Cond',
#  'Bsmt Qual',
#  'BsmtFin Type 1',
#  'Mas Vnr Type',
#  'Mas Vnr Area',
#  'Bsmt Half Bath',
#  'Bsmt Full Bath',
#  'Garage Cars',
#  'Garage Area',
#  'Total Bsmt SF',
#  'Bsmt Unf SF',
#  'BsmtFin SF 2',
#  'BsmtFin SF 1']

# %%
housing.dropna(subset = nulldrop_list)
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# Id
# 109   533352170           60        RL           NaN     13517   Pave   NaN
# 544   531379050           60        RL          43.0     11492   Pave   NaN
# 153   535304180           20        RL          68.0      7922   Pave   NaN
# 318   916386060           60        RL          73.0      9802   Pave   NaN
# 255   906425045           50        RL          82.0     14235   Pave   NaN
# ...         ...          ...       ...           ...       ...    ...   ...
# 1587  921126030           20        RL          79.0     11449   Pave   NaN
# 785   905377130           30        RL           NaN     12342   Pave   NaN
# 916   909253010           50        RL          57.0      7558   Pave   NaN
# 639   535179160           20        RL          80.0     10400   Pave   NaN
# 10    527162130           60        RL          60.0      7500   Pave   NaN
#
#      Lot Shape Land Contour Utilities  ... Screen Porch Pool Area Pool QC  \
# Id                                     ...
# 109        IR1          Lvl    AllPub  ...            0         0     NaN
# 544        IR1          Lvl    AllPub  ...            0         0     NaN
# 153        Reg          Lvl    AllPub  ...            0         0     NaN
# 318        Reg          Lvl    AllPub  ...            0         0     NaN
# 255        IR1          Lvl    AllPub  ...            0         0     NaN
# ...        ...          ...       ...  ...          ...       ...     ...
# 1587       IR1          HLS    AllPub  ...            0         0     NaN
# 785        IR1          Lvl    AllPub  ...            0         0     NaN
# 916        Reg          Bnk    AllPub  ...            0         0     NaN
# 639        Reg          Lvl    AllPub  ...            0         0     NaN
# 10         Reg          Lvl    AllPub  ...            0         0     NaN
#
#      Fence Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type  SalePrice
# Id
# 109    NaN          NaN        0       3     2010        WD      130500
# 544    NaN          NaN        0       4     2009        WD      220000
# 153    NaN          NaN        0       1     2010        WD      109000
# 318    NaN          NaN        0       4     2010        WD      174000
# 255    NaN          NaN        0       3     2010        WD      138500
# ...    ...          ...      ...     ...      ...        ...        ...
# 1587   NaN          NaN        0       1     2008        WD      298751
# 785    NaN          NaN        0       3     2009        WD       82500
# 916    NaN          NaN        0       3     2009        WD      177000
# 639    NaN          NaN        0      11     2009        WD      144000
# 10     NaN          NaN        0       6     2010        WD      189000
#
# [1969 rows x 80 columns]

# %%
1969/2051
# Out:
# 0.9600195026816187

# %%
# Since we've only dropped < 5% of the rows, this is acceptable

housing.dropna(subset = nulldrop_list, inplace = True)

# %%
null_features = housing.isnull().sum().sort_values(ascending = False).to_frame(name = 'nullcount')

null_features.head(20)
# Out:
#                 nullcount
# Pool QC              1961
# Misc Feature         1907
# Alley                1832
# Fence                1576
# Fireplace Qu          946
# Lot Frontage          315
# Garage Cond           103
# Garage Finish         103
# Garage Yr Blt         103
# Garage Type           103
# Garage Qual           103
# Roof Matl               0
# Exterior 2nd            0
# Year Remod/Add          0
# Exterior 1st            0
# Year Built              0
# Roof Style              0
# Mas Vnr Area            0
# Mas Vnr Type            0
# Overall Qual            0

# %%
null_tofill = null_features['nullcount'] > 0
null_features_tofill = null_features[null_tofill]
null_features_tofill
# Out:
#                nullcount
# Pool QC             1961
# Misc Feature        1907
# Alley               1832
# Fence               1576
# Fireplace Qu         946
# Lot Frontage         315
# Garage Cond          103
# Garage Finish        103
# Garage Yr Blt        103
# Garage Type          103
# Garage Qual          103

# %%
null_to_fill = null_features_tofill.index.to_list()
null_to_fill
# Out:
# ['Pool QC',
#  'Misc Feature',
#  'Alley',
#  'Fence',
#  'Fireplace Qu',
#  'Lot Frontage',
#  'Garage Cond',
#  'Garage Finish',
#  'Garage Yr Blt',
#  'Garage Type',
#  'Garage Qual']

# %%
garages = housing[['Garage Qual','Garage Finish','Garage Yr Blt', 'Garage Type', 'Garage Cond']]

# %%
garage_null = garages[garages['Garage Yr Blt'].isnull()]

# %%
garage_null.isnull().sum()  #this shows that these houses do not have garages
# Out:
# Garage Qual      103
# Garage Finish    103
# Garage Yr Blt    103
# Garage Type      103
# Garage Cond      103
# dtype: int64

# %%
housing[['Garage Yr Blt', 'Lot Frontage']].describe()
# Out:
#        Garage Yr Blt  Lot Frontage
# count    1866.000000   1654.000000
# mean     1978.647910     68.839178
# std        24.920352     23.177414
# min      1895.000000     21.000000
# 25%      1961.000000     57.000000
# 50%      1980.000000     68.000000
# 75%      2002.000000     80.000000
# max      2010.000000    313.000000

# %%
sns.pairplot(housing[['Garage Yr Blt', 'SalePrice']])

# %%
for feature in ['Pool QC',
 'Misc Feature',
 'Alley',
 'Fence',
 'Fireplace Qu']:
    
    print(housing[feature].value_counts())
    print('-------------')
# Out:
# Gd    4
# Fa    2
# TA    1
# Ex    1
# Name: Pool QC, dtype: int64
# -------------
# Shed    54
# Gar2     4
# Othr     2
# Elev     1
# TenC     1
# Name: Misc Feature, dtype: int64
# -------------
# Grvl    84
# Pave    53
# Name: Alley, dtype: int64
# -------------
# MnPrv    224
# GdPrv     80
# GdWo      79
# MnWw      10
# Name: Fence, dtype: int64
# -------------
# Gd    507
# TA    398
# Fa     59
# Po     30
# Ex     29
# Name: Fireplace Qu, dtype: int64
# -------------

# %%
housing['Fireplaces'].describe()
# Out:
# count    1969.000000
# mean        0.599797
# std         0.640217
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         4.000000
# Name: Fireplaces, dtype: float64

# %%
values_to_fill = {'Pool QC': 'NA',
 'Misc Feature': 'NA',
 'Alley': 'NA',
 'Fence': 'NA',
 'Fireplace Qu': 'NA',
 'Lot Frontage': 68, # median value
 'Garage Cond': 'NA',
 'Garage Finish': 'NA',
 'Garage Yr Blt': housing['Garage Yr Blt'].min(), #since there isn't a garage, we put it to the minimum value
 'Garage Type': 'NA',
 'Garage Qual': 'NA'}

# %%
housing.fillna(value = values_to_fill, inplace = True)

# %%
housing.isnull().sum().sort_values()
# Out:
# PID              0
# Fireplace Qu     0
# Fireplaces       0
# Functional       0
# TotRms AbvGrd    0
#                 ..
# Exterior 1st     0
# Roof Matl        0
# Roof Style       0
# Sale Type        0
# SalePrice        0
# Length: 80, dtype: int64

# %% [markdown]
# ## EDA: Continuous Features

# %%
numerical_columns = housing.select_dtypes(include = ['int64', 'float64']).columns.to_list()
numerical_columns
# Out:
# ['PID',
#  'MS SubClass',
#  'Lot Frontage',
#  'Lot Area',
#  'Overall Qual',
#  'Overall Cond',
#  'Year Built',
#  'Year Remod/Add',
#  'Mas Vnr Area',
#  'BsmtFin SF 1',
#  'BsmtFin SF 2',
#  'Bsmt Unf SF',
#  'Total Bsmt SF',
#  '1st Flr SF',
#  '2nd Flr SF',
#  'Low Qual Fin SF',
#  'Gr Liv Area',
#  'Bsmt Full Bath',
#  'Bsmt Half Bath',
#  'Full Bath',
#  'Half Bath',
#  'Bedroom AbvGr',
#  'Kitchen AbvGr',
#  'TotRms AbvGrd',
#  'Fireplaces',
#  'Garage Yr Blt',
#  'Garage Cars',
#  'Garage Area',
#  'Wood Deck SF',
#  'Open Porch SF',
#  'Enclosed Porch',
#  '3Ssn Porch',
#  'Screen Porch',
#  'Pool Area',
#  'Misc Val',
#  'Mo Sold',
#  'Yr Sold',
#  'SalePrice']

# %%
len(numerical_columns)
# Out:
# 38

# %%
continuous_features = ['Lot Frontage',
 'Lot Area',
 'Mas Vnr Area',
 'BsmtFin SF 1',
 'BsmtFin SF 2',
 'Bsmt Unf SF',
 'Total Bsmt SF',
 '1st Flr SF',
 '2nd Flr SF',
 'Low Qual Fin SF',
 'Gr Liv Area',
 'Garage Area',
 'Wood Deck SF',
 'Open Porch SF',
 'Enclosed Porch',
 '3Ssn Porch',
 'Screen Porch',
 'Pool Area',
 'Misc Val',
 'SalePrice']

# %%
len(continuous_features)
# Out:
# 20

# %%
def subplot_histograms(dataframe, list_of_columns, binsize = 10):
    
    nrows = int(np.ceil(len(list_of_columns)/2))
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize = (10, 5*nrows))
    
    ax = ax.ravel()
    
    for i, column in enumerate(list_of_columns): 
        ax[i].hist(dataframe[column], bins = binsize)
        
        ax[i].axvline(dataframe[column].median(), color='g', linestyle='dashed', linewidth=2)

        ax[i].set_title(str(column), fontsize = 14)
        
    plt.show()

# %%
sns.pairplot(housing[['Lot Frontage', 'Lot Area', 'SalePrice']])

# %%
subplot_histograms(housing, ['Lot Frontage', 'Lot Area'], binsize = 50)

# %%
housing[['Lot Frontage', 'Lot Area']].describe()
# Out:
#        Lot Frontage       Lot Area
# count   1969.000000    1969.000000
# mean      68.704926   10005.619604
# std       21.243908    6710.225845
# min       21.000000    1300.000000
# 25%       60.000000    7500.000000
# 50%       68.000000    9405.000000
# 75%       78.000000   11492.000000
# max      313.000000  159000.000000

# %%
housing[housing['Lot Area'] > 100000]
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# Id
# 2116  906426060           50        RL          68.0    159000   Pave    NA
# 2072  905301050           20        RL          68.0    115149   Pave    NA
#
#      Lot Shape Land Contour Utilities  ... Screen Porch Pool Area Pool QC  \
# Id                                     ...
# 2116       IR2          Low    AllPub  ...            0         0      NA
# 2072       IR2          Low    AllPub  ...            0         0      NA
#
#      Fence Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type  SalePrice
# Id
# 2116    NA         Shed      500       6     2007        WD      277000
# 2072    NA           NA        0       6     2007        WD      302000
#
# [2 rows x 80 columns]

# %%
housing = housing[housing['Lot Area'] < 100000]
housing.shape
# Out:
# (1967, 80)

# %%
housing[housing['Lot Frontage'] > 200]
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# Id
# 1499  908154235           60        RL         313.0     63887   Pave    NA
# 1266  535427070           20        RL         313.0     27650   Pave    NA
#
#      Lot Shape Land Contour Utilities  ... Screen Porch Pool Area Pool QC  \
# Id                                     ...
# 1499       IR3          Bnk    AllPub  ...            0       480      Gd
# 1266       IR2          HLS    AllPub  ...            0         0      NA
#
#      Fence Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type  SalePrice
# Id
# 1499    NA           NA        0       1     2008        New     160000
# 1266    NA           NA        0      11     2008        WD      242000
#
# [2 rows x 80 columns]

# %%
housing = housing[housing['Lot Frontage'] < 200]
housing.shape
# Out:
# (1965, 80)

# %%
sns.pairplot(housing[['Lot Frontage', 'Lot Area', 'SalePrice']])

# %%
plt.figure(figsize = (8, 6))
plt.scatter(data = housing, x = 'Mas Vnr Area', y = 'SalePrice')

# %%
plt.figure(figsize = (8, 6))
plt.hist(housing['Mas Vnr Area'], bins = 23)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
housing['Mas Vnr Area'].describe()
# Out:
# count    1965.000000
# mean      101.133333
# std       175.611786
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       164.000000
# max      1600.000000
# Name: Mas Vnr Area, dtype: float64

# %%
sns.pairplot(housing[['BsmtFin SF 1',
 'BsmtFin SF 2',
 'Bsmt Unf SF',
 'Total Bsmt SF', 'SalePrice']])

# %%
subplot_histograms(housing, ['BsmtFin SF 1',
 'BsmtFin SF 2',
 'Bsmt Unf SF',
 'Total Bsmt SF'], binsize = 25)

# %%
housing[['BsmtFin SF 1',
 'BsmtFin SF 2',
 'Bsmt Unf SF',
 'Total Bsmt SF']].describe()  #drop SF2
# Out:
#        BsmtFin SF 1  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF
# count   1965.000000   1965.000000  1965.000000    1965.000000
# mean     451.096183     49.638677   580.723664    1081.458524
# std      445.998865    167.861182   439.822588     401.488100
# min        0.000000      0.000000     0.000000     160.000000
# 25%        0.000000      0.000000   240.000000     811.000000
# 50%      384.000000      0.000000   485.000000    1008.000000
# 75%      741.000000      0.000000   816.000000    1326.000000
# max     4010.000000   1474.000000  2336.000000    5095.000000

# %%
housing.drop(columns = ['BsmtFin SF 2'], inplace = True)

# %%
housing.shape
# Out:
# (1965, 79)

# %%
sns.pairplot(housing[['1st Flr SF',
 '2nd Flr SF',
 'Low Qual Fin SF',
 'Gr Liv Area',
 'SalePrice']])

# %%
subplot_histograms(housing, ['1st Flr SF', '2nd Flr SF', 'Low Qual Fin SF',
                             'Gr Liv Area'], binsize = 10)

# %%
housing[['1st Flr SF',
 '2nd Flr SF',
 'Low Qual Fin SF',
 'Gr Liv Area']].describe() # drop low qual fin
# Out:
#         1st Flr SF   2nd Flr SF  Low Qual Fin SF  Gr Liv Area
# count  1965.000000  1965.000000      1965.000000  1965.000000
# mean   1161.593384   331.763868         5.622901  1498.980153
# std     383.931432   425.929012        51.956789   490.163006
# min     438.000000     0.000000         0.000000   438.000000
# 25%     879.000000     0.000000         0.000000  1133.000000
# 50%    1092.000000     0.000000         0.000000  1444.000000
# 75%    1402.000000   691.000000         0.000000  1728.000000
# max    5095.000000  1862.000000      1064.000000  5095.000000

# %%
housing.drop(columns = ['Low Qual Fin SF'], inplace = True)

# %%
housing.shape
# Out:
# (1965, 78)

# %%
housing[['Gr Liv Area', 'SalePrice']][housing['Gr Liv Area'] > 3000]
# Out:
#       Gr Liv Area  SalePrice
# Id
# 2331         3390     545224
# 1773         3228     430000
# 1765         3078     410000
# 16           3279     538000
# 2195         3395     200000
# 254          3222     320000
# 2667         3608     475000
# 66           3238     410000
# 910          3082     197000
# 2046         3086     200500
# 2451         3500     584500
# 423          3140     485000
# 2181         5095     183850
# 2738         3672     415000
# 1307         3493     295000

# %%
housing.drop(index = [2181, 2046, 910, 2195], inplace = True)

# %%
housing.shape
# Out:
# (1961, 78)

# %%
housing[['1st Flr SF', 'SalePrice']][housing['1st Flr SF'] > 3000]
# removing the outliers from Grd Liv Area fixed the outliers for 1st Flr SF as well
# Out:
#       1st Flr SF  SalePrice
# Id
# 1773        3228     430000

# %%
sns.pairplot(housing[['Open Porch SF',
 'Enclosed Porch',
 '3Ssn Porch',
 'Screen Porch', 'SalePrice']])

# %%
subplot_histograms(housing, ['Open Porch SF', 'Enclosed Porch', '3Ssn Porch','Screen Porch'], binsize = 10)

# %%
housing[['Open Porch SF',
 'Enclosed Porch',
 '3Ssn Porch',
 'Screen Porch',]].describe() #drop 3Ssn Porch
# Out:
#        Open Porch SF  Enclosed Porch   3Ssn Porch  Screen Porch
# count    1961.000000     1961.000000  1961.000000   1961.000000
# mean       47.505864       22.386537     2.710352     16.933707
# std        65.415899       59.803458    25.796115     57.904863
# min         0.000000        0.000000     0.000000      0.000000
# 25%         0.000000        0.000000     0.000000      0.000000
# 50%        28.000000        0.000000     0.000000      0.000000
# 75%        70.000000        0.000000     0.000000      0.000000
# max       547.000000      432.000000   508.000000    490.000000

# %%
housing['Porch Combined SF'] = housing[['Open Porch SF',
 'Enclosed Porch',
 '3Ssn Porch',
 'Screen Porch']].sum(axis = 1)

# %%
housing[['Open Porch SF', 'Enclosed Porch', '3Ssn Porch', 'Screen Porch', 'Porch Combined SF']].sample(10)
# Out:
#       Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  \
# Id
# 487               0               0           0             0
# 2226              0               0           0             0
# 1308              0              60           0             0
# 928               0               0           0             0
# 1486              0             164           0             0
# 1104              0               0           0             0
# 1592            122               0           0             0
# 674              40               0           0             0
# 1317             25             212           0             0
# 287              66             136           0             0
#
#       Porch Combined SF
# Id
# 487                   0
# 2226                  0
# 1308                 60
# 928                   0
# 1486                164
# 1104                  0
# 1592                122
# 674                  40
# 1317                237
# 287                 202

# %%
plt.scatter(data = housing, x = 'Porch Combined SF', y = 'SalePrice')

# %%
housing.drop(columns = ['Open Porch SF', 'Enclosed Porch', '3Ssn Porch', 'Screen Porch'], inplace = True)

# %%
housing.shape
# Out:
# (1961, 75)

# %%
sns.pairplot(housing[['Garage Area',
 'Pool Area',
 'Misc Val',
 'SalePrice']])

# %%
subplot_histograms(housing, ['Garage Area','Pool Area','Misc Val'], binsize = 20)

# %%
housing[['Garage Area',
 'Pool Area',
 'Misc Val']].describe()   #drop pool area, misc val
# Out:
#        Garage Area    Pool Area      Misc Val
# count  1961.000000  1961.000000   1961.000000
# mean    474.592045     1.977053     42.671596
# std     213.360184    34.886317    436.693936
# min       0.000000     0.000000      0.000000
# 25%     320.000000     0.000000      0.000000
# 50%     480.000000     0.000000      0.000000
# 75%     576.000000     0.000000      0.000000
# max    1356.000000   800.000000  12500.000000

# %%
housing[housing['Pool Area'] > 0]
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# Id
# 2351  527356020           60        RL          80.0     16692   Pave    NA
# 1567  914475020           80        RL          76.0      9880   Pave    NA
# 2499  532476050           80        RL         100.0     14330   Pave    NA
# 2231  909475230           20        RL          70.0     18044   Pave    NA
# 2358  527377030           20        RL          78.0     10140   Pave    NA
# 2736  905426150           80        RL          68.0     19690   Pave    NA
# 1941  535353050           20        RL          75.0      9532   Pave    NA
#
#      Lot Shape Land Contour Utilities  ... Pool Area Pool QC  Fence  \
# Id                                     ...
# 2351       IR1          Lvl    AllPub  ...       519      Fa  MnPrv
# 1567       Reg          Lvl    AllPub  ...       576      Gd  GdPrv
# 2499       IR1          Low    AllPub  ...       800      Gd  GdPrv
# 2231       IR1          HLS    AllPub  ...       228      Ex     NA
# 2358       Reg          Lvl    AllPub  ...       648      Fa  GdPrv
# 2736       IR1          Lvl    AllPub  ...       738      Gd  GdPrv
# 1941       Reg          Lvl    AllPub  ...       368      TA  GdPrv
#
#      Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  SalePrice  \
# Id
# 2351         TenC     2000       7    2006        WD      250000
# 1567           NA        0       7    2008        WD      171000
# 2499           NA        0       1    2006        WD      260000
# 2231           NA        0       8    2007        WD      315000
# 2358           NA        0       1    2006        WD      181000
# 2736           NA        0       8    2006        WD      274970
# 1941           NA        0       2    2007        WD      153000
#
#       Porch Combined SF
# Id
# 2351                552
# 1567                  0
# 2499                100
# 2231                233
# 2358                  0
# 2736                236
# 1941                  0
#
# [7 rows x 75 columns]

# %%
housing['Pool QC'].value_counts()
# Out:
# NA    1954
# Gd       3
# Fa       2
# TA       1
# Ex       1
# Name: Pool QC, dtype: int64

# %%
housing[housing['Misc Val'] > 0]
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# Id
# 1942  535353130           20        RL          68.0     15783   Pave    NA
# 12    527165230           20        RL          68.0      7980   Pave    NA
# 1957  535450190           50        RL          60.0      8064   Pave    NA
# 2351  527356020           60        RL          80.0     16692   Pave    NA
# 588   534129370           20        RL          80.0      9600   Pave    NA
# 1881  534252110           20        RL          68.0     12342   Pave    NA
# 420   527455280           20        RL          68.0     10710   Pave    NA
# 1885  534276160           20        RL          70.0      7535   Pave    NA
# 1734  528221050           20        RL          88.0     12216   Pave    NA
# 24    527402200           20        RL          68.0     11241   Pave    NA
# 265   907252120           20        RL          68.0     11423   Pave    NA
# 131   534451150           30        RL          55.0      5350   Pave    NA
# 1599  923227030           20        RL          68.0     17979   Pave    NA
# 1508  908250090           20        RL          68.0      9520   Pave    NA
# 3     526351010           20        RL          81.0     14267   Pave    NA
# 2480  531451290           60        RL          70.0      9370   Pave    NA
# 2669  902406030           20        RM          65.0      9750   Pave  Grvl
# 2545  534400120          190        RL          80.0      8800   Pave    NA
# 1190  534129060           20        RL          68.0     15387   Pave    NA
# 975   923225490           20        RL          62.0      9858   Pave    NA
# 1143  531384030           60        RL          43.0     14565   Pave    NA
# 1862  533352075           90        RL          68.0     18890   Pave    NA
# 2534  534201250           60        RL          72.0      8640   Pave    NA
# 140   535152050           20        RL          70.0      8197   Pave    NA
# 982   923252075           80        RL          62.0      7706   Pave    NA
# 1289  902105020           50        RM          60.0     10440   Pave  Grvl
# 2546  534403280           20        RL          80.0      8800   Pave    NA
# 1527  909252220           50        RL          63.0     15564   Pave    NA
# 896   908225290           20        RL          70.0     11767   Pave    NA
# 115   534152100           60        RL          80.0     10421   Pave    NA
# 399   527405160           20        RL          60.0      6960   Pave    NA
# 307   911204090           20   C (all)          66.0      8712   Grvl    NA
# 1263  535425060           20        RL          76.0     11355   Pave    NA
# 1921  535154080           20        RL          75.0      9750   Pave    NA
# 185   902327040           50        RM          60.0     10800   Pave    NA
# 752   903429110           70        RM          68.0      9928   Pave  Grvl
# 120   534276360           20        RL          77.0      9320   Pave    NA
# 903   909101010           50        RL          67.0     12354   Pave  Grvl
# 1262  535403010           20        RL          78.0     10180   Pave    NA
# 2606  535382130           50        RL          60.0     10800   Pave  Grvl
# 1381  905104110           20        RL          68.0     10265   Pave    NA
# 2592  535327210           20        RL          70.0     13300   Pave    NA
# 937   909452050           80        RL          68.0     13607   Pave    NA
# 77    531451280           60        RL          70.0     11218   Pave    NA
# 1330  903204095           40        RM          50.0      9100   Pave    NA
# 1872  534176140           20        RL          88.0     10738   Pave    NA
# 2676  903231070           50        RM          52.0      6240   Pave    NA
# 296   909427230           70        RL          66.0      9042   Pave    NA
# 801   906201050           80        RL          66.0     19255   Pave    NA
# 1443  907196040           60        RL          75.0     12192   Pave    NA
# 2343  527301010           20        RL          91.0     14145   Pave    NA
# 236   905426060           30        RL          85.0     10625   Pave    NA
# 1608  923400040           50        RL          75.0     12508   Pave    NA
# 349   527110020           80        RL          68.0      8530   Pave    NA
# 2168  908102100           20        RL          70.0      9170   Pave    NA
# 671   535403190           20        RL          62.0      8010   Pave    NA
# 964   916403200           60        RL          68.0      9839   Pave    NA
# 561   532377130           20        RL          80.0     10000   Pave    NA
# 602   534276040           20        RL          70.0      9100   Pave    NA
# 311   914475090           80        RL          74.0      9620   Pave    NA
#
#      Lot Shape Land Contour Utilities  ... Pool Area Pool QC  Fence  \
# Id                                     ...
# 1942       Reg          Lvl    AllPub  ...         0      NA  MnPrv
# 12         IR1          Lvl    AllPub  ...         0      NA  GdPrv
# 1957       Reg          Lvl    AllPub  ...         0      NA  MnPrv
# 2351       IR1          Lvl    AllPub  ...       519      Fa  MnPrv
# 588        Reg          Lvl    AllPub  ...         0      NA     NA
# 1881       IR1          Lvl    AllPub  ...         0      NA   GdWo
# 420        Reg          Lvl    AllPub  ...         0      NA     NA
# 1885       IR1          Lvl    AllPub  ...         0      NA   MnWw
# 1734       IR1          Lvl    AllPub  ...         0      NA     NA
# 24         IR1          Lvl    AllPub  ...         0      NA     NA
# 265        Reg          Lvl    AllPub  ...         0      NA  MnPrv
# 131        IR1          Lvl    AllPub  ...         0      NA   GdWo
# 1599       IR1          Lvl    AllPub  ...         0      NA   GdWo
# 1508       Reg          Bnk    AllPub  ...         0      NA  MnPrv
# 3          IR1          Lvl    AllPub  ...         0      NA     NA
# 2480       IR2          Lvl    AllPub  ...         0      NA     NA
# 2669       Reg          Lvl    AllPub  ...         0      NA     NA
# 2545       Reg          Lvl    AllPub  ...         0      NA  MnPrv
# 1190       IR1          Lvl    AllPub  ...         0      NA     NA
# 975        Reg          Lvl    AllPub  ...         0      NA   GdWo
# 1143       IR2          Lvl    AllPub  ...         0      NA     NA
# 1862       IR1          Lvl    AllPub  ...         0      NA     NA
# 2534       Reg          Lvl    AllPub  ...         0      NA     NA
# 140        Reg          Lvl    AllPub  ...         0      NA  MnPrv
# 982        Reg          Lvl    AllPub  ...         0      NA     NA
# 1289       Reg          Lvl    AllPub  ...         0      NA  MnPrv
# 2546       Reg          Lvl    AllPub  ...         0      NA  MnPrv
# 1527       Reg          Lvl    AllPub  ...         0      NA     NA
# 896        Reg          Lvl    AllPub  ...         0      NA     NA
# 115        Reg          Lvl    AllPub  ...         0      NA  MnPrv
# 399        Reg          Lvl    AllPub  ...         0      NA     NA
# 307        Reg          Bnk    AllPub  ...         0      NA     NA
# 1263       IR1          Lvl    AllPub  ...         0      NA  MnPrv
# 1921       Reg          Lvl    AllPub  ...         0      NA     NA
# 185        Reg          Lvl    AllPub  ...         0      NA     NA
# 752        Reg          Lvl    AllPub  ...         0      NA     NA
# 120        IR1          Lvl    AllPub  ...         0      NA     NA
# 903        Reg          Lvl    AllPub  ...         0      NA  GdPrv
# 1262       IR1          Lvl    AllPub  ...         0      NA   GdWo
# 2606       Reg          Lvl    AllPub  ...         0      NA     NA
# 1381       IR1          Lvl    AllPub  ...         0      NA  MnPrv
# 2592       Reg          Lvl    AllPub  ...         0      NA     NA
# 937        IR1          Lvl    AllPub  ...         0      NA     NA
# 77         Reg          Lvl    AllPub  ...         0      NA  GdPrv
# 1330       Reg          Lvl    AllPub  ...         0      NA     NA
# 1872       IR1          Lvl    AllPub  ...         0      NA  MnPrv
# 2676       Reg          Lvl    AllPub  ...         0      NA  MnPrv
# 296        Reg          Lvl    AllPub  ...         0      NA  GdPrv
# 801        IR1          Lvl    AllPub  ...         0      NA     NA
# 1443       IR1          Lvl    AllPub  ...         0      NA     NA
# 2343       Reg          Lvl    AllPub  ...         0      NA     NA
# 236        Reg          Lvl    AllPub  ...         0      NA     NA
# 1608       IR1          Lvl    AllPub  ...         0      NA     NA
# 349        IR1          Lvl    AllPub  ...         0      NA     NA
# 2168       Reg          Lvl    AllPub  ...         0      NA  GdPrv
# 671        Reg          Lvl    AllPub  ...         0      NA     NA
# 964        IR1          Lvl    AllPub  ...         0      NA     NA
# 561        Reg          Lvl    AllPub  ...         0      NA   GdWo
# 602        Reg          Lvl    AllPub  ...         0      NA     NA
# 311        Reg          Lvl    AllPub  ...         0      NA  GdPrv
#
#      Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  SalePrice  \
# Id
# 1942         Shed      400       6    2007        WD      112500
# 12           Shed      500       3    2010        WD      185000
# 1957         Shed     2000       7    2007        WD      122900
# 2351         TenC     2000       7    2006        WD      250000
# 588          Shed      650       8    2009        WD      163000
# 1881         Shed      600       8    2007        WD      139900
# 420          Shed     1200       7    2009        WD      148800
# 1885         Shed      480       6    2007        WD      120000
# 1734         Shed     2000       6    2007        WD      203000
# 24           Shed      700       3    2010        WD      149000
# 265          Shed     2000       5    2010        WD      272000
# 131          Shed      450       5    2010        WD       76500
# 1599         Shed      500       2    2008        WD      152500
# 1508         Gar2     3000       5    2008        WD       99000
# 3            Gar2    12500       6    2010        WD      172000
# 2480         Othr     3000      10    2006        WD      248500
# 2669         Gar2     4500       7    2006        WD      125000
# 2545         Shed      460       6    2006        WD      185900
# 1190         Shed      450       8    2008        WD      215000
# 975          Shed      600      11    2009        WD      130000
# 1143         Shed     2000      11    2008        WD      189000
# 1862         Gar2     8300       8    2007        WD      190000
# 2534         Shed      455       6    2006        WD      155000
# 140          Shed      300       2    2010        WD      214000
# 982          Shed      700       8    2009        WD      131250
# 1289         Shed     1150       6    2008        WD      256000
# 2546         Shed      700       3    2006        WD      160000
# 1527         Shed      400       1    2008        WD      147500
# 896          Shed      900       6    2009        WD      120000
# 115          Shed      500       3    2010        WD      196500
# 399          Shed      500      11    2009        WD      120500
# 307          Shed       54       6    2010        WD       55993
# 1263         Othr     6500       4    2008        WD      186000
# 1921         Shed      500       4    2007        COD     157900
# 185          Shed     1200       6    2010        WD      139000
# 752          Shed      400       6    2009        WD      179900
# 120          Shed      400       1    2010        WD      128950
# 903          Shed      800       8    2009      ConLI     110000
# 1262         Shed      450       6    2008        WD      139000
# 2606         Shed      500       4    2006        WD      170000
# 1381         Shed      600       7    2008        WD      145000
# 2592         Shed      400       6    2006        WD      159000
# 937          Shed     1500       4    2009        WD      208000
# 77           Shed      400       5    2010        WD      189000
# 1330         Shed      600       8    2008        WD       79500
# 1872         Shed      400      11    2007        WD      158500
# 2676         Shed      400       9    2006        WD      114500
# 296          Shed     2500       5    2010        WD      266500
# 801          Shed      600       9    2009        WD      156500
# 1443         Shed     4500       5    2008        WD      235000
# 2343         Shed      400       5    2006        WD      202500
# 236          Shed      400       5    2010        COD      83000
# 1608         Shed     1300       7    2008        WD      160000
# 349          Shed      700       5    2009        WD      168500
# 2168         Shed      400       4    2007        WD      140000
# 671          Shed      450       9    2009        WD      143500
# 964          Shed     2500       2    2009        WD      204000
# 561          Shed      400       3    2009        WD      131400
# 602          Shed      450      10    2009        WD      127500
# 311          Shed       80       5    2010        WD      190000
#
#       Porch Combined SF
# Id
# 1942                324
# 12                   21
# 1957                  0
# 2351                552
# 588                  11
# 1881                 36
# 420                 162
# 1885                285
# 1734                 23
# 24                    0
# 265                   0
# 131                   0
# 1599                  0
# 1508                  0
# 3                    36
# 2480                309
# 2669                  0
# 2545                236
# 1190                254
# 975                   0
# 1143                 74
# 1862                169
# 2534                330
# 140                  73
# 982                   0
# 1289               1027
# 2546                116
# 1527                  0
# 896                 252
# 115                 222
# 399                   0
# 307                   0
# 1263                448
# 1921                275
# 185                 196
# 752                  28
# 120                   0
# 903                  46
# 1262                 48
# 2606                 21
# 1381                  0
# 2592                323
# 937                 112
# 77                  104
# 1330                  0
# 1872                  0
# 2676                  0
# 296                  60
# 801                   0
# 1443                 36
# 2343                 45
# 236                  77
# 1608                156
# 349                  72
# 2168                184
# 671                  42
# 964                  24
# 561                   0
# 602                   0
# 311                  26
#
# [60 rows x 75 columns]

# %%
housing.drop(columns = ['Pool Area', 'Misc Val'], inplace = True)

# %%
housing.shape
# Out:
# (1961, 73)

# %% [markdown]
# ## Data Wrangling: Changing Ordinal features to Discrete

# %%
categorical_features = housing.select_dtypes(include = 'object').columns.to_list()
categorical_features
# Out:
# ['MS Zoning',
#  'Street',
#  'Alley',
#  'Lot Shape',
#  'Land Contour',
#  'Utilities',
#  'Lot Config',
#  'Land Slope',
#  'Neighborhood',
#  'Condition 1',
#  'Condition 2',
#  'Bldg Type',
#  'House Style',
#  'Roof Style',
#  'Roof Matl',
#  'Exterior 1st',
#  'Exterior 2nd',
#  'Mas Vnr Type',
#  'Exter Qual',
#  'Exter Cond',
#  'Foundation',
#  'Bsmt Qual',
#  'Bsmt Cond',
#  'Bsmt Exposure',
#  'BsmtFin Type 1',
#  'BsmtFin Type 2',
#  'Heating',
#  'Heating QC',
#  'Central Air',
#  'Electrical',
#  'Kitchen Qual',
#  'Functional',
#  'Fireplace Qu',
#  'Garage Type',
#  'Garage Finish',
#  'Garage Qual',
#  'Garage Cond',
#  'Paved Drive',
#  'Pool QC',
#  'Fence',
#  'Misc Feature',
#  'Sale Type']

# %%
ordinal_features = ['Lot Shape', 'Utilities', 'Land Slope',
                   'Exter Qual','Exter Cond', 'Bsmt Qual','Bsmt Cond','Bsmt Exposure',
                    'BsmtFin Type 1','BsmtFin Type 2', 'Heating QC', 'Electrical','Kitchen Qual',
                    'Functional', 'Fireplace Qu', 'Garage Finish', 'Garage Qual','Garage Cond',
                    'Paved Drive','Pool QC','Fence']

# %%
len(ordinal_features)  #Overall Qual and Overall Cond data values are already integers
# Out:
# 21

# %%
for feature in ordinal_features:
    
    print(housing[feature].value_counts())
    print('-------------------------')
# Out:
# Reg    1234
# IR1     669
# IR2      50
# IR3       8
# Name: Lot Shape, dtype: int64
# -------------------------
# AllPub    1960
# NoSeWa       1
# Name: Utilities, dtype: int64
# -------------------------
# Gtl    1869
# Mod      84
# Sev       8
# Name: Land Slope, dtype: int64
# -------------------------
# TA    1193
# Gd     669
# Ex      78
# Fa      21
# Name: Exter Qual, dtype: int64
# -------------------------
# TA    1696
# Gd     213
# Fa      44
# Ex       7
# Po       1
# Name: Exter Cond, dtype: int64
# -------------------------
# TA    883
# Gd    842
# Ex    175
# Fa     60
# Po      1
# Name: Bsmt Qual, dtype: int64
# -------------------------
# TA    1802
# Gd      87
# Fa      64
# Po       5
# Ex       3
# Name: Bsmt Cond, dtype: int64
# -------------------------
# No    1317
# Av     284
# Gd     197
# Mn     163
# Name: Bsmt Exposure, dtype: int64
# -------------------------
# GLQ    598
# Unf    590
# ALQ    292
# BLQ    200
# Rec    180
# LwQ    101
# Name: BsmtFin Type 1, dtype: int64
# -------------------------
# Unf    1717
# Rec      80
# LwQ      60
# BLQ      47
# ALQ      34
# GLQ      23
# Name: BsmtFin Type 2, dtype: int64
# -------------------------
# Ex    1027
# TA     562
# Gd     311
# Fa      59
# Po       2
# Name: Heating QC, dtype: int64
# -------------------------
# SBrkr    1799
# FuseA     127
# FuseF      28
# FuseP       6
# Mix         1
# Name: Electrical, dtype: int64
# -------------------------
# TA    1000
# Gd     777
# Ex     143
# Fa      41
# Name: Kitchen Qual, dtype: int64
# -------------------------
# Typ     1845
# Min1      38
# Min2      37
# Mod       22
# Maj1      10
# Maj2       6
# Sev        2
# Sal        1
# Name: Functional, dtype: int64
# -------------------------
# NA    945
# Gd    503
# TA    395
# Fa     59
# Po     30
# Ex     29
# Name: Fireplace Qu, dtype: int64
# -------------------------
# Unf    808
# RFn    562
# Fin    490
# NA     101
# Name: Garage Finish, dtype: int64
# -------------------------
# TA    1760
# NA     101
# Fa      77
# Gd      18
# Ex       3
# Po       2
# Name: Garage Qual, dtype: int64
# -------------------------
# TA    1796
# NA     101
# Fa      44
# Gd      11
# Po       7
# Ex       2
# Name: Garage Cond, dtype: int64
# -------------------------
# Y    1795
# N     129
# P      37
# Name: Paved Drive, dtype: int64
# -------------------------
# NA    1954
# Gd       3
# Fa       2
# TA       1
# Ex       1
# Name: Pool QC, dtype: int64
# -------------------------
# NA       1569
# MnPrv     223
# GdPrv      80
# GdWo       79
# MnWw       10
# Name: Fence, dtype: int64
# -------------------------

# %%
0.9 * housing.shape[0]
# Out:
# 1764.9

# %%
housing.drop(columns = ['PID', 'Utilities'], inplace = True)

# %%
housing.shape
# Out:
# (1961, 71)

# %%
ordinal_features.remove('Utilities')

# %%
len(ordinal_features)
# Out:
# 20

# %%
ordinal_features.sort()

# %%
print(ordinal_features)
# Out:
# ['Bsmt Cond', 'Bsmt Exposure', 'Bsmt Qual', 'BsmtFin Type 1', 'BsmtFin Type 2', 'Electrical', 'Exter Cond', 'Exter Qual', 'Fence', 'Fireplace Qu', 'Functional', 'Garage Cond', 'Garage Finish', 'Garage Qual', 'Heating QC', 'Kitchen Qual', 'Land Slope', 'Lot Shape', 'Paved Drive', 'Pool QC']

# %%
housing.replace(to_replace = {
    'Bsmt Cond': {'Ex': 5, 'Gd': 4, 'TA':3, 'Fa':2, 'Po': 1, 'NA': 0},
    'Bsmt Exposure': {'Gd': 4, 'Av':3, 'Mn':2, 'No': 1, 'NA': 0},
    'Bsmt Qual': {'Ex': 5, 'Gd': 4, 'TA':3, 'Fa':2, 'Po': 1, 'NA': 0},
    'BsmtFin Type 1': {'GLQ': 6, 'ALQ': 5, 'BLQ': 4, 'Rec': 3, 'LwQ': 2, 'Unf': 1, 'NA': 0},
    'BsmtFin Type 2': {'GLQ': 6, 'ALQ': 5, 'BLQ': 4, 'Rec': 3, 'LwQ': 2, 'Unf': 1, 'NA': 0},
    'Electrical': {'SBrkr': 4, 'FuseA': 3, 'FuseF':2, 'FuseP':1, 'Mix': 0},
    'Exter Cond': {'Ex': 4, 'Gd': 3, 'TA':2, 'Fa':1, 'Po': 0},
    'Exter Qual': {'Ex': 4, 'Gd': 3, 'TA':2, 'Fa':1, 'Po': 0},
    'Fence': {'GdPrv': 4, 'MnPrv': 3, 'GdWo': 2, 'MnWw': 1, 'NA': 0},
    'Fireplace Qu': {'Ex': 5, 'Gd': 4, 'TA':3, 'Fa':2, 'Po': 1, 'NA': 0},
    'Functional': {'Typ': 7, 'Min1': 6, 'Min2': 5, 'Mod': 4, 'Maj1': 3, 'Maj2': 2, 'Sev': 1, 'Sal': 0},
    'Garage Cond': {'Ex': 5, 'Gd': 4, 'TA':3, 'Fa':2, 'Po': 1, 'NA': 0},
    'Garage Finish': {'Fin':3, 'RFn':2, 'Unf': 1, 'NA': 0},
    'Garage Qual': {'Ex': 5, 'Gd': 4, 'TA':3, 'Fa':2, 'Po': 1, 'NA': 0},
    'Heating QC': {'Ex': 4, 'Gd': 3, 'TA':2, 'Fa':1, 'Po': 0},
    'Kitchen Qual': {'Ex': 4, 'Gd': 3, 'TA':2, 'Fa':1, 'Po': 0},
    'Land Slope': {'Gtl': 2, 'Mod':1, 'Sev': 0},
    'Lot Shape': {'Reg':3, 'IR1':2, 'IR2': 1, 'IR3': 0},
    'Paved Drive': {'Y': 2, 'P':1, 'N': 0},
    'Pool QC': {'Ex': 4, 'Gd': 3, 'TA':2, 'Fa':1, 'NA': 0}
}, inplace = True)

# %%
for feature in ordinal_features:
    
    print(housing[feature].value_counts())
    print('--------------------------')
# Out:
# 3    1802
# 4      87
# 2      64
# 1       5
# 5       3
# Name: Bsmt Cond, dtype: int64
# --------------------------
# 1    1317
# 3     284
# 4     197
# 2     163
# Name: Bsmt Exposure, dtype: int64
# --------------------------
# 3    883
# 4    842
# 5    175
# 2     60
# 1      1
# Name: Bsmt Qual, dtype: int64
# --------------------------
# 6    598
# 1    590
# 5    292
# 4    200
# 3    180
# 2    101
# Name: BsmtFin Type 1, dtype: int64
# --------------------------
# 1    1717
# 3      80
# 2      60
# 4      47
# 5      34
# 6      23
# Name: BsmtFin Type 2, dtype: int64
# --------------------------
# 4    1799
# 3     127
# 2      28
# 1       6
# 0       1
# Name: Electrical, dtype: int64
# --------------------------
# 2    1696
# 3     213
# 1      44
# 4       7
# 0       1
# Name: Exter Cond, dtype: int64
# --------------------------
# 2    1193
# 3     669
# 4      78
# 1      21
# Name: Exter Qual, dtype: int64
# --------------------------
# 0    1569
# 3     223
# 4      80
# 2      79
# 1      10
# Name: Fence, dtype: int64
# --------------------------
# 0    945
# 4    503
# 3    395
# 2     59
# 1     30
# 5     29
# Name: Fireplace Qu, dtype: int64
# --------------------------
# 7    1845
# 6      38
# 5      37
# 4      22
# 3      10
# 2       6
# 1       2
# 0       1
# Name: Functional, dtype: int64
# --------------------------
# 3    1796
# 0     101
# 2      44
# 4      11
# 1       7
# 5       2
# Name: Garage Cond, dtype: int64
# --------------------------
# 1    808
# 2    562
# 3    490
# 0    101
# Name: Garage Finish, dtype: int64
# --------------------------
# 3    1760
# 0     101
# 2      77
# 4      18
# 5       3
# 1       2
# Name: Garage Qual, dtype: int64
# --------------------------
# 4    1027
# 2     562
# 3     311
# 1      59
# 0       2
# Name: Heating QC, dtype: int64
# --------------------------
# 2    1000
# 3     777
# 4     143
# 1      41
# Name: Kitchen Qual, dtype: int64
# --------------------------
# 2    1869
# 1      84
# 0       8
# Name: Land Slope, dtype: int64
# --------------------------
# 3    1234
# 2     669
# 1      50
# 0       8
# Name: Lot Shape, dtype: int64
# --------------------------
# 2    1795
# 0     129
# 1      37
# Name: Paved Drive, dtype: int64
# --------------------------
# 0    1954
# 3       3
# 1       2
# 4       1
# 2       1
# Name: Pool QC, dtype: int64
# --------------------------

# %%
int_features = housing.select_dtypes(include = 'int64').columns.to_list()
int_features
# Out:
# ['MS SubClass',
#  'Lot Area',
#  'Lot Shape',
#  'Land Slope',
#  'Overall Qual',
#  'Overall Cond',
#  'Year Built',
#  'Year Remod/Add',
#  'Exter Qual',
#  'Exter Cond',
#  'Bsmt Qual',
#  'Bsmt Cond',
#  'Bsmt Exposure',
#  'BsmtFin Type 1',
#  'BsmtFin Type 2',
#  'Heating QC',
#  'Electrical',
#  '1st Flr SF',
#  '2nd Flr SF',
#  'Gr Liv Area',
#  'Full Bath',
#  'Half Bath',
#  'Bedroom AbvGr',
#  'Kitchen AbvGr',
#  'Kitchen Qual',
#  'TotRms AbvGrd',
#  'Functional',
#  'Fireplaces',
#  'Fireplace Qu',
#  'Garage Finish',
#  'Garage Qual',
#  'Garage Cond',
#  'Paved Drive',
#  'Wood Deck SF',
#  'Pool QC',
#  'Fence',
#  'Mo Sold',
#  'Yr Sold',
#  'SalePrice',
#  'Porch Combined SF']

# %%
int_features = set(int_features).difference(set(continuous_features))

# %%
int_features
# Out:
# {'Bedroom AbvGr',
#  'Bsmt Cond',
#  'Bsmt Exposure',
#  'Bsmt Qual',
#  'BsmtFin Type 1',
#  'BsmtFin Type 2',
#  'Electrical',
#  'Exter Cond',
#  'Exter Qual',
#  'Fence',
#  'Fireplace Qu',
#  'Fireplaces',
#  'Full Bath',
#  'Functional',
#  'Garage Cond',
#  'Garage Finish',
#  'Garage Qual',
#  'Half Bath',
#  'Heating QC',
#  'Kitchen AbvGr',
#  'Kitchen Qual',
#  'Land Slope',
#  'Lot Shape',
#  'MS SubClass',
#  'Mo Sold',
#  'Overall Cond',
#  'Overall Qual',
#  'Paved Drive',
#  'Pool QC',
#  'Porch Combined SF',
#  'TotRms AbvGrd',
#  'Year Built',
#  'Year Remod/Add',
#  'Yr Sold'}

# %%
housing.select_dtypes(include = 'float64').columns
# Out:
# Index(['Lot Frontage', 'Mas Vnr Area', 'BsmtFin SF 1', 'Bsmt Unf SF',
#        'Total Bsmt SF', 'Bsmt Full Bath', 'Bsmt Half Bath', 'Garage Yr Blt',
#        'Garage Cars', 'Garage Area'],
#       dtype='object')

# %%
discrete_features = list(int_features) + ['Garage Cars', 'Bsmt Full Bath', 'Bsmt Half Bath', 'Garage Yr Blt']

# %%
discrete_features.sort()
discrete_features
# Out:
# ['Bedroom AbvGr',
#  'Bsmt Cond',
#  'Bsmt Exposure',
#  'Bsmt Full Bath',
#  'Bsmt Half Bath',
#  'Bsmt Qual',
#  'BsmtFin Type 1',
#  'BsmtFin Type 2',
#  'Electrical',
#  'Exter Cond',
#  'Exter Qual',
#  'Fence',
#  'Fireplace Qu',
#  'Fireplaces',
#  'Full Bath',
#  'Functional',
#  'Garage Cars',
#  'Garage Cond',
#  'Garage Finish',
#  'Garage Qual',
#  'Garage Yr Blt',
#  'Half Bath',
#  'Heating QC',
#  'Kitchen AbvGr',
#  'Kitchen Qual',
#  'Land Slope',
#  'Lot Shape',
#  'MS SubClass',
#  'Mo Sold',
#  'Overall Cond',
#  'Overall Qual',
#  'Paved Drive',
#  'Pool QC',
#  'Porch Combined SF',
#  'TotRms AbvGrd',
#  'Year Built',
#  'Year Remod/Add',
#  'Yr Sold']

# %%
discrete_features.remove('MS SubClass') # MS Subclass has data of type int, but is a nominal feature
discrete_features.remove('Porch Combined SF')
len(discrete_features)   

# according to readme, we have 23 ordinal + 14 discrete features = 37. 
# 'Utilities' was removed earlier, making the final total = 36
# Out:
# 36

# %% [markdown]
# ## EDA: Discrete Features

# %%
discrete_features.sort()
discrete_features
# Out:
# ['Bedroom AbvGr',
#  'Bsmt Cond',
#  'Bsmt Exposure',
#  'Bsmt Full Bath',
#  'Bsmt Half Bath',
#  'Bsmt Qual',
#  'BsmtFin Type 1',
#  'BsmtFin Type 2',
#  'Electrical',
#  'Exter Cond',
#  'Exter Qual',
#  'Fence',
#  'Fireplace Qu',
#  'Fireplaces',
#  'Full Bath',
#  'Functional',
#  'Garage Cars',
#  'Garage Cond',
#  'Garage Finish',
#  'Garage Qual',
#  'Garage Yr Blt',
#  'Half Bath',
#  'Heating QC',
#  'Kitchen AbvGr',
#  'Kitchen Qual',
#  'Land Slope',
#  'Lot Shape',
#  'Mo Sold',
#  'Overall Cond',
#  'Overall Qual',
#  'Paved Drive',
#  'Pool QC',
#  'TotRms AbvGrd',
#  'Year Built',
#  'Year Remod/Add',
#  'Yr Sold']

# %%
housing['Year Built'].describe()
# Out:
# count    1961.000000
# mean     1971.860275
# std        30.208052
# min      1872.000000
# 25%      1954.000000
# 50%      1975.000000
# 75%      2001.000000
# max      2010.000000
# Name: Year Built, dtype: float64

# %%
housing['House Age'] = 2020 - housing['Year Built']
housing['House Age'].describe()
# Out:
# count    1961.000000
# mean       48.139725
# std        30.208052
# min        10.000000
# 25%        19.000000
# 50%        45.000000
# 75%        66.000000
# max       148.000000
# Name: House Age, dtype: float64

# %%
housing['Year Remod/Add'].describe()
# Out:
# count    1961.000000
# mean     1984.375829
# std        20.868270
# min      1950.000000
# 25%      1965.000000
# 50%      1993.000000
# 75%      2004.000000
# max      2010.000000
# Name: Year Remod/Add, dtype: float64

# %%
housing['House Remod Yrs'] = 2020 - housing['Year Remod/Add']
housing['House Remod Yrs'].describe()
# Out:
# count    1961.000000
# mean       35.624171
# std        20.868270
# min        10.000000
# 25%        16.000000
# 50%        27.000000
# 75%        55.000000
# max        70.000000
# Name: House Remod Yrs, dtype: float64

# %%
housing['House Remod Yrs'].describe()
# Out:
# count    1961.000000
# mean       35.624171
# std        20.868270
# min        10.000000
# 25%        16.000000
# 50%        27.000000
# 75%        55.000000
# max        70.000000
# Name: House Remod Yrs, dtype: float64

# %%
housing['Yr Sold'].describe()
# Out:
# count    1961.000000
# mean     2007.777155
# std         1.315065
# min      2006.000000
# 25%      2007.000000
# 50%      2008.000000
# 75%      2009.000000
# max      2010.000000
# Name: Yr Sold, dtype: float64

# %%
housing.drop(columns = ['Yr Sold', 'Year Remod/Add', 'Year Built'], inplace = True)
housing.shape
# Out:
# (1961, 70)

# %%
housing['Mo Sold'].describe()
# Out:
# count    1961.000000
# mean        6.213157
# std         2.745023
# min         1.000000
# 25%         4.000000
# 50%         6.000000
# 75%         8.000000
# max        12.000000
# Name: Mo Sold, dtype: float64

# %%
sns.pairplot(housing[['House Remod Yrs', 'House Age', 'Mo Sold', 'SalePrice']])

# %%
# don't drop anything

# %%
sns.pairplot(housing[['Exter Cond','Exter Qual', 
                      'Overall Cond', 'Overall Qual', 
                      'Functional', 'SalePrice']])

# %%
subplot_histograms(housing, 
                   ['Exter Cond','Exter Qual', 'Overall Cond', 'Overall Qual', 'Functional'],
                   binsize = 20
                  )

# %%
housing[['Exter Cond','Exter Qual', 'Overall Cond', 'Overall Qual']].corr()
# Out:
#               Exter Cond  Exter Qual  Overall Cond  Overall Qual
# Exter Cond      1.000000    0.018208      0.416959     -0.006167
# Exter Qual      0.018208    1.000000     -0.168032      0.740346
# Overall Cond    0.416959   -0.168032      1.000000     -0.113639
# Overall Qual   -0.006167    0.740346     -0.113639      1.000000

# %%
housing['Exterior Qual/Cond'] = housing[['Exter Cond','Exter Qual']].sum(axis = 1)

# %%
housing['Overall Qual/Cond'] = housing[['Overall Cond','Overall Qual']].sum(axis = 1)

# %%
sns.pairplot(housing[['Overall Qual/Cond', 'Exterior Qual/Cond', 'SalePrice']])

# %%
housing.shape
# Out:
# (1961, 72)

# %%
housing.drop(columns = ['Overall Cond', 'Overall Qual', 'Exter Cond', 'Exter Qual'], inplace = True)  
# remove after feature engineering

# %%
housing.shape
# Out:
# (1961, 68)

# %%
sns.pairplot(housing[['Bsmt Exposure','Bsmt Qual','Bsmt Cond', 'BsmtFin Type 1', 'BsmtFin Type 2', 'SalePrice']])

# %%
housing[['Bsmt Exposure','Bsmt Qual', 'Bsmt Cond', 'BsmtFin Type 1', 'BsmtFin Type 2']].describe()
# Out:
#        Bsmt Exposure    Bsmt Qual    Bsmt Cond  BsmtFin Type 1  BsmtFin Type 2
# count    1961.000000  1961.000000  1961.000000     1961.000000     1961.000000
# mean        1.674146     3.576237     3.009689        3.661397        1.312086
# std         1.054819     0.697975     0.305407        2.064418        0.939769
# min         1.000000     1.000000     1.000000        1.000000        1.000000
# 25%         1.000000     3.000000     3.000000        1.000000        1.000000
# 50%         1.000000     4.000000     3.000000        4.000000        1.000000
# 75%         2.000000     4.000000     3.000000        6.000000        1.000000
# max         4.000000     5.000000     5.000000        6.000000        6.000000

# %%
housing.drop(columns = ['BsmtFin Type 2'], inplace = True) #skewed distribution, no clear linear relationship
housing.shape
# Out:
# (1961, 67)

# %%
sns.pairplot(housing[['Bedroom AbvGr', 'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'SalePrice']])

# %%
# nothing to drop...yet

# %%
subplot_histograms(housing, 
                   ['Bedroom AbvGr', 'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd'],
                   binsize = 10
                  )

# %%
# nothing to drop...yet

# %%
sns.pairplot(housing[['Half Bath', 'Full Bath', 'Bsmt Full Bath', 'Bsmt Half Bath', 'SalePrice']])

# %%
# nothing to drop...yet

# %%
sns.pairplot(housing[['Lot Shape', 'Land Slope', 'Fence', 'Paved Drive', 'Pool QC', 'SalePrice']])

# %%
# nothing to drop...yet

# %%
sns.pairplot(housing[['Fireplaces', 'Fireplace Qu', 'Heating QC', 'SalePrice']])

# %%
# nothing to drop...yet

# %%
housing['Garage Yr Blt'].describe()
# Out:
# count    1961.000000
# mean     1974.338093
# std        30.521395
# min      1895.000000
# 25%      1958.000000
# 50%      1978.000000
# 75%      2001.000000
# max      2010.000000
# Name: Garage Yr Blt, dtype: float64

# %%
housing['Garage Age'] = 2020 - housing['Garage Yr Blt']
housing['Garage Age'].describe()
# Out:
# count    1961.000000
# mean       45.661907
# std        30.521395
# min        10.000000
# 25%        19.000000
# 50%        42.000000
# 75%        62.000000
# max       125.000000
# Name: Garage Age, dtype: float64

# %%
sns.pairplot(housing[['Garage Age','Garage Cars','Garage Finish','Garage Cond', 'Garage Qual','SalePrice']])

# %%
housing[['Garage Age','Garage Cars','Garage Finish','Garage Cond', 'Garage Qual','SalePrice']].corr()
# Out:
#                Garage Age  Garage Cars  Garage Finish  Garage Cond  \
# Garage Age       1.000000    -0.728912      -0.647414    -0.637119
# Garage Cars     -0.728912     1.000000       0.571486     0.545266
# Garage Finish   -0.647414     0.571486       1.000000     0.471380
# Garage Cond     -0.637119     0.545266       0.471380     1.000000
# Garage Qual     -0.662195     0.558058       0.477548     0.949490
# SalePrice       -0.551871     0.654593       0.554522     0.256798
#
#                Garage Qual  SalePrice
# Garage Age       -0.662195  -0.551871
# Garage Cars       0.558058   0.654593
# Garage Finish     0.477548   0.554522
# Garage Cond       0.949490   0.256798
# Garage Qual       1.000000   0.279775
# SalePrice         0.279775   1.000000

# %%
housing['Garage Qual/Cond'] = housing[['Garage Cond', 'Garage Qual']].sum(axis = 1)

# %%
housing.shape
# Out:
# (1961, 69)

# %%
housing.drop(columns = ['Garage Cond', 'Garage Qual', 'Garage Yr Blt'], inplace = True)

# %%
housing.shape
# Out:
# (1961, 66)

# %%
# nothing to drop...yet

# %% [markdown]
# ## EDA: Nominal

# %%
categorical_features = housing.select_dtypes(include = 'object').columns.to_list()

# %%
nominal_ = set(categorical_features).difference(set(discrete_features))
nominal_
# Out:
# {'Alley',
#  'Bldg Type',
#  'Central Air',
#  'Condition 1',
#  'Condition 2',
#  'Exterior 1st',
#  'Exterior 2nd',
#  'Foundation',
#  'Garage Type',
#  'Heating',
#  'House Style',
#  'Land Contour',
#  'Lot Config',
#  'MS Zoning',
#  'Mas Vnr Type',
#  'Misc Feature',
#  'Neighborhood',
#  'Roof Matl',
#  'Roof Style',
#  'Sale Type',
#  'Street'}

# %%
nominal_features = [
    'Alley',
    'Bldg Type',
    'Central Air',
    'Condition 1',
    'Condition 2',
    'Exterior 1st',
    'Exterior 2nd',
    'Foundation',
    'Garage Type',
    'Heating',
    'House Style',
    'Land Contour',
    'Lot Config',
    'MS Zoning',
    'MS SubClass', #added in
    'Mas Vnr Type',
    'Misc Feature',
    'Neighborhood',
    'Roof Matl',
    'Roof Style',
    'Sale Type',
    'Street'
]

# %%
len(nominal_features)  #PID was dropped earlier
# Out:
# 22

# %%
for feature in nominal_features:
    
    print(housing[feature].value_counts(normalize = True))
    print('------------------------------')
# Out:
# NA      0.930648
# Grvl    0.042835
# Pave    0.026517
# Name: Alley, dtype: float64
# ------------------------------
# 1Fam      0.834268
# TwnhsE    0.080571
# Twnhs     0.035186
# Duplex    0.028047
# 2fmCon    0.021928
# Name: Bldg Type, dtype: float64
# ------------------------------
# Y    0.939317
# N    0.060683
# Name: Central Air, dtype: float64
# ------------------------------
# Norm      0.864865
# Feedr     0.049465
# Artery    0.034676
# RRAn      0.016828
# PosN      0.013768
# RRAe      0.010199
# PosA      0.005609
# RRNn      0.003060
# RRNe      0.001530
# Name: Condition 1, dtype: float64
# ------------------------------
# Norm      0.986741
# Feedr     0.005609
# Artery    0.002550
# PosA      0.001530
# PosN      0.001530
# RRNn      0.001020
# RRAe      0.000510
# RRAn      0.000510
# Name: Condition 2, dtype: float64
# ------------------------------
# VinylSd    0.354921
# MetalSd    0.163692
# HdBoard    0.148394
# Wd Sdng    0.133605
# Plywood    0.073432
# CemntBd    0.043855
# BrkFace    0.029577
# WdShing    0.020908
# AsbShng    0.015298
# Stucco     0.012239
# BrkComm    0.001530
# Stone      0.001020
# CBlock     0.000510
# ImStucc    0.000510
# AsphShn    0.000510
# Name: Exterior 1st, dtype: float64
# ------------------------------
# VinylSd    0.352881
# MetalSd    0.160122
# HdBoard    0.135135
# Wd Sdng    0.127996
# Plywood    0.087710
# CmentBd    0.043855
# Wd Shng    0.030087
# BrkFace    0.016318
# AsbShng    0.014278
# Stucco     0.014278
# Brk Cmn    0.008669
# ImStucc    0.005609
# AsphShn    0.001530
# Stone      0.001020
# CBlock     0.000510
# Name: Exterior 2nd, dtype: float64
# ------------------------------
# PConc     0.456400
# CBlock    0.429883
# BrkTil    0.110148
# Stone     0.002550
# Wood      0.001020
# Name: Foundation, dtype: float64
# ------------------------------
# Attchd     0.594595
# Detchd     0.262111
# BuiltIn    0.065273
# NA         0.051504
# Basment    0.013259
# 2Types     0.009179
# CarPort    0.004080
# Name: Garage Type, dtype: float64
# ------------------------------
# GasA    0.986232
# GasW    0.010199
# Grav    0.002550
# OthW    0.001020
# Name: Heating, dtype: float64
# ------------------------------
# 1Story    0.510454
# 2Story    0.294238
# 1.5Fin    0.107598
# SLvl      0.047425
# SFoyer    0.024987
# 2.5Unf    0.007139
# 1.5Unf    0.006119
# 2.5Fin    0.002040
# Name: House Style, dtype: float64
# ------------------------------
# Lvl    0.901581
# HLS    0.042325
# Bnk    0.036716
# Low    0.019378
# Name: Land Contour, dtype: float64
# ------------------------------
# Inside     0.735849
# Corner     0.168791
# CulDSac    0.062723
# FR2        0.028557
# FR3        0.004080
# Name: Lot Config, dtype: float64
# ------------------------------
# RL         0.780214
# RM         0.156553
# FV         0.047425
# C (all)    0.009179
# RH         0.006629
# Name: MS Zoning, dtype: float64
# ------------------------------
# 20     0.374809
# 60     0.194289
# 50     0.098419
# 120    0.065783
# 30     0.048445
# 160    0.044875
# 70     0.044875
# 80     0.043345
# 90     0.028047
# 190    0.021928
# 85     0.013768
# 75     0.007649
# 180    0.005609
# 45     0.005609
# 40     0.002040
# 150    0.000510
# Name: MS SubClass, dtype: float64
# ------------------------------
# None       0.592555
# BrkFace    0.317695
# Stone      0.084141
# BrkCmn     0.005609
# Name: Mas Vnr Type, dtype: float64
# ------------------------------
# NA      0.969403
# Shed    0.027027
# Gar2    0.002040
# Othr    0.001020
# TenC    0.000510
# Name: Misc Feature, dtype: float64
# ------------------------------
# NAmes      0.151963
# CollgCr    0.090770
# OldTown    0.080571
# Edwards    0.063743
# NridgHt    0.060683
# Somerst    0.060173
# Gilbert    0.056094
# Sawyer     0.054564
# NWAmes     0.044365
# SawyerW    0.040796
# Mitchel    0.039776
# BrkSide    0.037736
# Crawfor    0.035696
# IDOTRR     0.032126
# NoRidge    0.024477
# Timber     0.023967
# StoneBr    0.019378
# SWISU      0.015298
# MeadowV    0.012239
# ClearCr    0.011729
# Blmngtn    0.011219
# BrDale     0.009689
# Veenker    0.008669
# NPkVill    0.008669
# Blueste    0.003060
# Greens     0.001530
# GrnHill    0.000510
# Landmrk    0.000510
# Name: Neighborhood, dtype: float64
# ------------------------------
# CompShg    0.987761
# Tar&Grv    0.007139
# WdShngl    0.002550
# WdShake    0.002040
# Membran    0.000510
# Name: Roof Matl, dtype: float64
# ------------------------------
# Gable      0.785824
# Hip        0.196838
# Gambrel    0.006119
# Flat       0.006119
# Mansard    0.003570
# Shed       0.001530
# Name: Roof Style, dtype: float64
# ------------------------------
# WD       0.872514
# New      0.074452
# COD      0.031617
# ConLD    0.006119
# CWD      0.005099
# ConLI    0.003570
# ConLw    0.002550
# Con      0.002040
# Oth      0.002040
# Name: Sale Type, dtype: float64
# ------------------------------
# Pave    0.99694
# Grvl    0.00306
# Name: Street, dtype: float64
# ------------------------------

# %%
# drop Condition 2, Misc Feature, Roof Matl, Street (Skewed data)

# %%
housing.shape
# Out:
# (1961, 66)

# %%
housing.drop(columns = ['Condition 2', 'Misc Feature', 'Roof Matl', 'Street'], inplace = True)

# %%
housing.shape
# Out:
# (1961, 62)

# %%
nominal_dropped = ['Condition 2', 'Misc Feature', 'Roof Matl', 'Street']

# %%
nominal_filtered = set(nominal_features).difference(set(nominal_dropped))

# %%
nominal_filtered
# Out:
# {'Alley',
#  'Bldg Type',
#  'Central Air',
#  'Condition 1',
#  'Exterior 1st',
#  'Exterior 2nd',
#  'Foundation',
#  'Garage Type',
#  'Heating',
#  'House Style',
#  'Land Contour',
#  'Lot Config',
#  'MS SubClass',
#  'MS Zoning',
#  'Mas Vnr Type',
#  'Neighborhood',
#  'Roof Style',
#  'Sale Type'}

# %%
housing_dummied = pd.get_dummies(data = housing, columns = nominal_filtered)

# %%
housing_dummied.dtypes.value_counts()
# Out:
# uint8      150
# int64       34
# float64     10
# dtype: int64

# %%
housing_dummied.shape
# Out:
# (1961, 194)

# %%
dummy_columns = [col for col in housing_dummied.columns if 'NA' in col]
dummy_columns
# Out:
# ['Neighborhood_NAmes', 'Alley_NA', 'Garage Type_NA']

# %%
housing_dummied.drop(columns = ['Garage Type_NA', 'Alley_NA'], inplace = True)
housing_dummied.shape
# Out:
# (1961, 192)

# %%
dummy_columns = [col for col in housing_dummied if 'NA' in col]
dummy_columns
# Out:
# ['Neighborhood_NAmes']

# %%
housing_dummied.to_csv('datasets/Train_cleaned.csv')

# %%
housing_dummied.head()
# Out:
#      Lot Frontage  Lot Area  Lot Shape  Land Slope  Mas Vnr Area  Bsmt Qual  \
# Id
# 109          68.0     13517          2           2         289.0          3
# 544          43.0     11492          2           2         132.0          4
# 153          68.0      7922          3           2           0.0          3
# 318          73.0      9802          3           2           0.0          4
# 255          82.0     14235          2           2           0.0          2
#
#      Bsmt Cond  Bsmt Exposure  BsmtFin Type 1  BsmtFin SF 1  ...  \
# Id                                                           ...
# 109          3              1               6         533.0  ...
# 544          3              1               6         637.0  ...
# 153          3              1               6         731.0  ...
# 318          3              1               1           0.0  ...
# 255          4              1               1           0.0  ...
#
#      Exterior 2nd_Stucco  Exterior 2nd_VinylSd  Exterior 2nd_Wd Sdng  \
# Id
# 109                    0                     0                     0
# 544                    0                     1                     0
# 153                    0                     1                     0
# 318                    0                     1                     0
# 255                    0                     0                     0
#
#      Exterior 2nd_Wd Shng  Garage Type_2Types  Garage Type_Attchd  \
# Id
# 109                     0                   0                   1
# 544                     0                   0                   1
# 153                     0                   0                   0
# 318                     0                   0                   0
# 255                     0                   0                   0
#
#      Garage Type_Basment  Garage Type_BuiltIn  Garage Type_CarPort  \
# Id
# 109                    0                    0                    0
# 544                    0                    0                    0
# 153                    0                    0                    0
# 318                    0                    1                    0
# 255                    0                    0                    0
#
#      Garage Type_Detchd
# Id
# 109                   0
# 544                   0
# 153                   1
# 318                   0
# 255                   1
#
# [5 rows x 192 columns]
